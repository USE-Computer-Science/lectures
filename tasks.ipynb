# %% [markdown]
# <a href="https://colab.research.google.com/github/USE-Computer-Science/lectures/blob/main/tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lst1 = [1, 29, 14, 36, 20]
lst2 = [5, 15, 64, 30, 16, 15, 40, 15]

# %% [markdown]
# **Среднее арифметическое** — число, равное сумме всех чисел множества, делённой на их количество

# %%
# напишите функцию, которая возвращает среднее арифметическое заданного списка

# %% [markdown]
# **Медиана**  – число, находящееся в середине числового ряда, если его упорядочить по возрастанию.
# <br>
# Например в ряду: 1, 2, 3, 7, 9 — медиана = 3.
# <br>
# <br>
# Если количество чисел чётное, то за медиану принимают среднее двух стоящих в центре чисел.
# <br>
# Например в ряду: 1, 2, 3, 7 — медиана = $\frac{2+3}{2}=2.5$.
# <br>

# %%
# напишите функцию, которая возвращает медиану заданного списка

# %% [markdown]
# **Мода** – наиболее часто встречающееся в числовом ряду значение. Например в ряду: 1, 2, 2, 3, 7, 9 — мода = 2.

# %%
# напишите функцию, которая возвращает моду заданного списка

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
lst = ['foo', 'bar', 'baz', 'qux', 'quux', 'corge']

# %%
# напишите функцию, которая заменяет значения элементов списка на их обратные индексы, используя только прямые индексы
